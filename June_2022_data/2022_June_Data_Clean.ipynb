# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# Reading in 2022 June 1st data
df1 <- read_csv("data/2022_June_1.csv")

# Renaming Column Names
colnames(df1) <- make.names(colnames(df1))
tidy_df1 <- df1 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df1 <- rename(tidy_df1,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df1 <- tidy_df1 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df1, "data/tidy_2022_June_1.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                   file
# 457  -- 30 columns 9 columns 'data/2022_June_1.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_1.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_1.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_1.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_1.csv'
# ... ... .......... ......... ......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 2nd data
df2 <- read_csv("data/2022_June_2.csv")

# Renaming Column Names
colnames(df2) <- make.names(colnames(df2))
tidy_df2 <- df2 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df2 <- rename(tidy_df2,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df2 <- tidy_df2 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df2, "data/tidy_2022_June_2.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                   file
# 457  -- 30 columns 9 columns 'data/2022_June_2.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_2.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_2.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_2.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_2.csv'
# ... ... .......... ......... ......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 3rd data
df3 <- read_csv("data/2022_June_3.csv")

# Renaming Column Names
colnames(df3) <- make.names(colnames(df3))
tidy_df3 <- df3 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df3 <- rename(tidy_df3,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df3 <- tidy_df3 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df3, "data/tidy_2022_June_3.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                   file
# 457  -- 30 columns 9 columns 'data/2022_June_3.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_3.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_3.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_3.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_3.csv'
# ... ... .......... ......... ......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 4th data
df4 <- read_csv("data/2022_June_4.csv")

# Renaming Column Names
colnames(df4) <- make.names(colnames(df4))
tidy_df4 <- df4 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df4 <- rename(tidy_df4,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df4 <- tidy_df4 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df4, "data/tidy_2022_June_4.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                   file
# 457  -- 30 columns 9 columns 'data/2022_June_4.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_4.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_4.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_4.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_4.csv'
# ... ... .......... ......... ......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 5th data
df5 <- read_csv("data/2022_June_5.csv")

# Renaming Column Names
colnames(df5) <- make.names(colnames(df5))
tidy_df5 <- df5 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df5 <- rename(tidy_df5,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df5 <- tidy_df5 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df5, "data/tidy_2022_June_5.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                   file
# 457  -- 30 columns 9 columns 'data/2022_June_5.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_5.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_5.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_5.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_5.csv'
# ... ... .......... ......... ......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 6th data
df6 <- read_csv("data/2022_June_6.csv")

# Renaming Column Names
colnames(df6) <- make.names(colnames(df6))
tidy_df6 <- df6 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df6 <- rename(tidy_df6,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df6 <- tidy_df6 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df6, "data/tidy_2022_June_6.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                   file
# 457  -- 30 columns 9 columns 'data/2022_June_6.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_6.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_6.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_6.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_6.csv'
# ... ... .......... ......... ......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 7th data
df7 <- read_csv("data/2022_June_7.csv")

# Renaming Column Names
colnames(df7) <- make.names(colnames(df7))
tidy_df7 <- df7 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df7 <- rename(tidy_df7,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df7 <- tidy_df7 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df7, "data/tidy_2022_June_7.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                   file
# 457  -- 30 columns 9 columns 'data/2022_June_7.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_7.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_7.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_7.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_7.csv'
# ... ... .......... ......... ......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 8th data
df8 <- read_csv("data/2022_June_8.csv")

# Renaming Column Names
colnames(df8) <- make.names(colnames(df8))
tidy_df8 <- df8 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df8 <- rename(tidy_df8,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df8 <- tidy_df8 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df8, "data/tidy_2022_June_8.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                   file
# 457  -- 30 columns 9 columns 'data/2022_June_8.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_8.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_8.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_8.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_8.csv'
# ... ... .......... ......... ......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 9th data
df9 <- read_csv("data/2022_June_9.csv")

# Renaming Column Names
colnames(df9) <- make.names(colnames(df9))
tidy_df9 <- df9 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df9 <- rename(tidy_df9,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df9 <- tidy_df9 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df9, "data/tidy_2022_June_9.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                   file
# 457  -- 30 columns 9 columns 'data/2022_June_9.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_9.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_9.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_9.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_9.csv'
# ... ... .......... ......... ......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 10th data
df10 <- read_csv("data/2022_June_10.csv")

# Renaming Column Names
colnames(df10) <- make.names(colnames(df10))
tidy_df10 <- df10 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df10 <- rename(tidy_df10,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df10 <- tidy_df10 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df10, "data/tidy_2022_June_10.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                    file
# 457  -- 30 columns 9 columns 'data/2022_June_10.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_10.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_10.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_10.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_10.csv'
# ... ... .......... ......... .......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 11th data
df11 <- read_csv("data/2022_June_11.csv")

# Renaming Column Names
colnames(df11) <- make.names(colnames(df11))
tidy_df11 <- df11 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df11 <- rename(tidy_df11,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df11 <- tidy_df11 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df11, "data/tidy_2022_June_11.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                    file
# 457  -- 30 columns 9 columns 'data/2022_June_11.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_11.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_11.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_11.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_11.csv'
# ... ... .......... ......... .......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 12th data
df12 <- read_csv("data/2022_June_12.csv")

# Renaming Column Names
colnames(df12) <- make.names(colnames(df12))
tidy_df12 <- df12 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df12 <- rename(tidy_df12,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df12 <- tidy_df12 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df12, "data/tidy_2022_June_12.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                    file
# 457  -- 30 columns 9 columns 'data/2022_June_12.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_12.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_12.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_12.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_12.csv'
# ... ... .......... ......... .......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 13th data
df13 <- read_csv("data/2022_June_13.csv")

# Renaming Column Names
colnames(df13) <- make.names(colnames(df13))
tidy_df13 <- df13 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df13 <- rename(tidy_df13,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df13 <- tidy_df13 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df13, "data/tidy_2022_June_13.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                    file
# 457  -- 30 columns 9 columns 'data/2022_June_13.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_13.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_13.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_13.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_13.csv'
# ... ... .......... ......... .......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 14th data
df14 <- read_csv("data/2022_June_14.csv")

# Renaming Column Names
colnames(df14) <- make.names(colnames(df14))
tidy_df14 <- df14 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df14 <- rename(tidy_df14,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df14 <- tidy_df14 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df14, "data/tidy_2022_June_14.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                    file
# 457  -- 30 columns 9 columns 'data/2022_June_14.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_14.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_14.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_14.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_14.csv'
# ... ... .......... ......... .......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 15th data
df15 <- read_csv("data/2022_June_15.csv")

# Renaming Column Names
colnames(df15) <- make.names(colnames(df15))
tidy_df15 <- df15 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df15 <- rename(tidy_df15,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df15 <- tidy_df15 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df15, "data/tidy_2022_June_15.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                    file
# 457  -- 30 columns 9 columns 'data/2022_June_15.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_15.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_15.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_15.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_15.csv'
# ... ... .......... ......... .......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 16th data
df16 <- read_csv("data/2022_June_16.csv")

# Renaming Column Names
colnames(df16) <- make.names(colnames(df16))
tidy_df16 <- df16 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df16 <- rename(tidy_df16,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df16 <- tidy_df16 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df16, "data/tidy_2022_June_16.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                    file
# 457  -- 30 columns 9 columns 'data/2022_June_16.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_16.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_16.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_16.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_16.csv'
# ... ... .......... ......... .......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 17th data
df17 <- read_csv("data/2022_June_17.csv")

# Renaming Column Names
colnames(df17) <- make.names(colnames(df17))
tidy_df17 <- df17 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df17 <- rename(tidy_df17,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df17 <- tidy_df17 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df17, "data/tidy_2022_June_17.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                    file
# 457  -- 30 columns 9 columns 'data/2022_June_17.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_17.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_17.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_17.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_17.csv'
# ... ... .......... ......... .......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 18th data
df18 <- read_csv("data/2022_June_18.csv")

# Renaming Column Names
colnames(df18) <- make.names(colnames(df18))
tidy_df18 <- df18 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df18 <- rename(tidy_df18,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df18 <- tidy_df18 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df18, "data/tidy_2022_June_18.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                    file
# 457  -- 30 columns 9 columns 'data/2022_June_18.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_18.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_18.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_18.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_18.csv'
# ... ... .......... ......... .......................
# See problems(...) for more details.
# ”

# %%
# Reading in 2022 June 19th data
df19 <- read_csv("data/2022_June_19.csv")

# Renaming Column Names
colnames(df19) <- make.names(colnames(df19))
tidy_df19 <- df19 %>%
    select(Temp...C., Rel.Hum...., Wind.Spd..km.h., Visibility..km., Stn.Press..kPa., Weather) %>%
    filter(Weather != "NA") 
tidy_df19 <- rename(tidy_df19,
       Temp = Temp...C., 
       Humid = Rel.Hum...., 
       Wind_Spd = Wind.Spd..km.h.,
       Vis = Visibility..km., 
       Press = Stn.Press..kPa.)

# Mutating weather column as factor
tidy_df19 <- tidy_df19 %>%
    mutate(Weather = as_factor(Weather))

# Saving tidy data
write_csv(tidy_df19, "data/tidy_2022_June_19.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_logical(),
#   `Longitude (x)` = col_double(),
#   `Latitude (y)` = col_double(),
#   `Station Name` = col_character(),
#   `Climate ID` = col_double(),
#   `Date/Time (LST)` = col_datetime(format = ""),
#   Year = col_double(),
#   Month = col_character(),
#   Day = col_character(),
#   `Time (LST)` = col_time(format = ""),
#   `Temp (°C)` = col_double(),
#   `Dew Point Temp (°C)` = col_double(),
#   `Rel Hum (%)` = col_double(),
#   `Wind Dir (10s deg)` = col_double(),
#   `Wind Spd (km/h)` = col_double(),
#   `Visibility (km)` = col_double(),
#   `Stn Press (kPa)` = col_double(),
#   Weather = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “264 parsing failures.
# row col   expected    actual                    file
# 457  -- 30 columns 9 columns 'data/2022_June_19.csv'
# 458  -- 30 columns 9 columns 'data/2022_June_19.csv'
# 459  -- 30 columns 9 columns 'data/2022_June_19.csv'
# 460  -- 30 columns 9 columns 'data/2022_June_19.csv'
# 461  -- 30 columns 9 columns 'data/2022_June_19.csv'
# ... ... .......... ......... .......................
# See problems(...) for more details.
# ”
