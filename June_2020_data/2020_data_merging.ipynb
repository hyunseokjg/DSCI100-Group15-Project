# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# Reading in all tidy data of June 2020

df1 <- read_csv("tidy_data/tidy_2020_June_1.csv")
df2 <- read_csv("tidy_data/tidy_2020_June_2.csv")
df3 <- read_csv("tidy_data/tidy_2020_June_3.csv")
df4 <- read_csv("tidy_data/tidy_2020_June_4.csv")
df5 <- read_csv("tidy_data/tidy_2020_June_5.csv")
df6 <- read_csv("tidy_data/tidy_2020_June_6.csv")
df7 <- read_csv("tidy_data/tidy_2020_June_7.csv")
df8 <- read_csv("tidy_data/tidy_2020_June_8.csv")
df9 <- read_csv("tidy_data/tidy_2020_June_9.csv")
df10 <- read_csv("tidy_data/tidy_2020_June_10.csv")
df11 <- read_csv("tidy_data/tidy_2020_June_11.csv")
df12 <- read_csv("tidy_data/tidy_2020_June_12.csv")
df13 <- read_csv("tidy_data/tidy_2020_June_13.csv")
df14 <- read_csv("tidy_data/tidy_2020_June_14.csv")
df15 <- read_csv("tidy_data/tidy_2020_June_15.csv")
df16 <- read_csv("tidy_data/tidy_2020_June_16.csv")
df17 <- read_csv("tidy_data/tidy_2020_June_17.csv")
df18 <- read_csv("tidy_data/tidy_2020_June_18.csv")
df19 <- read_csv("tidy_data/tidy_2020_June_19.csv")
df20 <- read_csv("tidy_data/tidy_2020_June_20.csv")
df21 <- read_csv("tidy_data/tidy_2020_June_21.csv")
df22 <- read_csv("tidy_data/tidy_2020_June_22.csv")
df23 <- read_csv("tidy_data/tidy_2020_June_23.csv")
df24 <- read_csv("tidy_data/tidy_2020_June_24.csv")
df25 <- read_csv("tidy_data/tidy_2020_June_25.csv")
df26 <- read_csv("tidy_data/tidy_2020_June_26.csv")
df27 <- read_csv("tidy_data/tidy_2020_June_27.csv")
df28 <- read_csv("tidy_data/tidy_2020_June_28.csv")
df29 <- read_csv("tidy_data/tidy_2020_June_29.csv")
df30 <- read_csv("tidy_data/tidy_2020_June_30.csv")
# Out:
# Parsed with column specification:
# cols(
#   Temp = col_double(),
#   Humid = col_double(),
#   Wind_Spd = col_double(),
#   Vis = col_double(),
#   Press = col_double(),
#   Weather = col_character()
# )
#
# Parsed with column specification:
# cols(
#   Temp = col_double(),
#   Humid = col_double(),
#   Wind_Spd = col_double(),
#   Vis = col_double(),
#   Press = col_double(),
#   Weather = col_character()
# )
#
# Parsed with column specification:
# cols(
#   Temp = col_double(),
#   Humid = col_double(),
#   Wind_Spd = col_double(),
#   Vis = col_double(),
#   Press = col_double(),
#   Weather = col_character()
# )
#
# Parsed with column specification:
# cols(
#   Temp = col_double(),
#   Humid = col_double(),
#   Wind_Spd = col_double(),
#   Vis = col_double(),
#   Press = col_double(),
#   Weather = col_character()
# )
#
# Parsed with column specification:
# cols(
#   Temp = col_double(),
#   Humid = col_double(),
#   Wind_Spd = col_double(),
#   Vis = col_double(),
# ...

# %%
# Merging multiple data file into single table

df_final <- bind_rows(df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, 
                      df11, df12, df13, df14, df15, df16, df17, df18, df19, df20,
                      df21, df22, df23, df24, df25, df26, df27, df28, df29, df30)

# %%
# Saving the merged table into .csv file

write_csv(df_final, "tidy_data/trainging_set1.csv")
